# %% [markdown]
# ### Тема “Введение в математических анализ”

# %% [markdown]
# ###### 1. Как относятся друг к другу множество и последовательность? (в ответе использовать слова типа: часть, целое, общее, частное, родитель, дочерний субъект и т.д.)
#
# Если последовательность это набор элементов множества, то множество и последовательность относятся друг к другу как целое и его часть.

# %% [markdown]
# ###### 2. Прочитать высказывания математической логики, построить их отрицания и установить истинность.

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# 1) Для любого $y$ принадлежащего интервалу от 0 до 1 включительно, $sgn(y)=1$
# 2) Для любого натурального n большего двух, существуют такие натуральные x,y,z, что  $x^n = y^n + z^n$
# 3) Для любого действительного $x$ существует такое действительное $X$, что $X$ больше $x$
# 4) Для любого комплексного $x$ не существует такого комплексного $y$, что  $y$ больше или меньше $x$
# 5) Для любого $y$ принадлежащего интервалу от 0 до $пи$ пополам включительно, существует такое $eps$ большее 0, что $sin(y) < sin(y+eps)$
# 6) Для любого $y$ принадлежащего интервалу от 0 до $пи$ пополам, существует такое $eps$ большее 0, что $cos(y) > cos(y+eps)$
# 7) Существует такое x, что оно не приналдлежит множеству множеств натуральных, целых, дробных, действительных и комплеексных чисел

# %% [markdown]
# ###### Отрицание
#
# ![2.png](attachment:2.png)

# %% [markdown]
# ###### Истинност
# 1) Ложь
# 2) Ложь
# 3) Истина
# 4) Истина
# 5) Ложь
# 6) Истина
# 7) Ложь

# %% [markdown]
# ### Тема “Множество”

# %% [markdown]
# ###### 1) Даны три множества a,b и с. Необходимо выполнить все изученные виды бинарных операций над всеми комбинациями множеств.
#
# a = {1,2,3,4,5}
# b = {2,4,6,8,10}
# c = {10}
#
# 1) Объединение:
# $a \cup b = ${1,2,3,4,5,6,8,10}
# $b \cup c = ${2,4,6,8,10}
# $a \cup c = ${1,2,3,4,5,10}
# 2) Пересичение:
# $a \cap b = ${2,4}
# $b \cap c = ${10}
# $a \cap c = ${}
# 3) Разность:
# a \ b = {1,3,5}
# b \ c = {2,4,6,8}
# a \ c = {1,2,3,4,5}
# 4) Симметричная разность:
# $(a \cap b)$ \ $(a \cup b) = ${1,3,5,6,8,10}
# $(b \cap c)$ \ $(b \cup c)= ${2,4,6,8}
# $(a \cap c)$ \ $(a \cup c)= ${1,2,3,4,5,10}

# %% [markdown]
# ###### 2) *Выполнить задание 1 на языке Python

# %%
a = {1,2,3,4,5}   
b = {2,4,6,8,10}   
c = {10}

# %%
#Объединение
print(a.union(b))
print(b.union(c))
print(a.union(c))
# Out:
# {1, 2, 3, 4, 5, 6, 8, 10}
# {2, 4, 6, 8, 10}
# {1, 2, 3, 4, 5, 10}

# %%
#Пересечение
print(a.intersection(b))
print(b.intersection(c))
print(a.intersection(c))
# Out:
# {2, 4}
# {10}
# set()

# %%
#Разность
print(a - b)
print(b - c)
print(a - c)
# Out:
# {1, 3, 5}
# {8, 2, 4, 6}
# {1, 2, 3, 4, 5}

# %%
#Симметричная разность
print(a.symmetric_difference(b))
print(b.symmetric_difference(c))
print(a.symmetric_difference(c))
# Out:
# {1, 3, 5, 6, 8, 10}
# {2, 4, 6, 8}
# {1, 2, 3, 4, 5, 10}

# %% [markdown]
# ### Тема 3 “Последовательность”

# %% [markdown]
# ###### 1) Даны 4 последовательности. Необходимо:
#     a. исследовать их на монотонность;
#     b. исследовать на ограниченность;
#     c. найти пятый по счету член.

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.linspace(1, 100, 100)
y1 = 2**x - x
plt.xlabel("x")
plt.ylabel("y")
plt.grid()     
plt.plot(x, y1) 

#Функция монотонна
#Ограничена снизу 0
#Пятый член последовательности = 27

# %%
x = np.linspace(2, 100, 100)
y2 = 1 / (1 - x)
plt.xlabel("x")
plt.ylabel("y")
plt.grid()     
plt.plot(x, y2)
#Функция монотонна
#Ограничена сверху и слева 0
#Пятый член последовательности = - 0.2

# %%
x = np.linspace(1, 100, 100)
y3 = ((-1)**x) + np.sqrt(2*x)
plt.xlabel("x")
plt.ylabel("y")
plt.grid()     
plt.plot(x, y3)
#Функция монотонна
#Ограничена снизу и слева 0
#Пятый член последовательности = 2.16

# %%
x = np.linspace(1, 100, 100)
y4 = ((-1)**(2*x)) + 1/(x**2)
plt.xlabel("x")
plt.ylabel("y")
plt.grid()     
plt.plot(x, y4)
#Функция монотонна
#Ограничена слева 0 и снизу 1
#Пятый член последовательности = 1.04

# %% [markdown]
# ###### 2) Найти 12-й член заданной неявно последовательности
#
# $a_1 = 128,  a_{n+1} - a_n = 6$
#
# $a_12 = a_1 + 6*11 = 194$

# %% [markdown]
# ###### 3) *На языке Python предложить алгоритм вычисляющий численно предел с точностью
#
# $\lim_{n\to+\infty} \frac{n}{\sqrt[n]{n!}}$

# %%
import math
def lim(n):
    return n/(math.factorial(n)**(1/n))
eps = 0.001
i = 1
while lim(i+1)-lim(i) > eps:
    i+=1
print(lim(i))
# Out:
# 2.617701998673183

# %% [markdown]
# ###### 4)*Предложить оптимизацию алгоритма, полученного в задании 3, ускоряющую его сходимость.

# %%
# Из очевидного, всё тоже самое что и в предыдущем задании, только увеличть шаг. Однако можно будет легко получить переполнение
import math
def lim(n):
    return n/(math.factorial(n)**(1/n))
eps = 0.001
i = 1
while lim(i+1)-lim(i) > eps:
    i+=5
print(lim(i))
# Вероятно можно как-то преобразовать выражение, или выделить закономерности, которые позволят, не вычислять весь факториал.
# Out:
# 2.6206071640168287
