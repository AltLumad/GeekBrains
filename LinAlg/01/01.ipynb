# %% [markdown]
# # Урок 1

# %% [markdown]
# ### Линейное пространство. Основные понятия. Часть 1

# %% [markdown]
# 1. Исследовать на линейную зависимость:
# $f_1(x)=e^x,f_2(x)=1,f_3(x)=x+1,f_4(x)=x−e^x$

# %% [markdown]
# ##### Решение
#
# $f_3(x)=x+f_2(x)$
# $f_4(x) = x - f_1(x)$
# $f_3(x)-f_2(x) = -(f_4(x) + f_1(x))$
# Ответ:  вектора линейно зависимы.

# %% [markdown]
# 2. Исследовать на линейную зависимость:
# $f_1(x)=2, f_2(x)=x, f_3(x)=x^2,f_4(x)=(x+1)^2$

# %% [markdown]
# ##### Решение
#
# $f_4(x)=x^2+2x + 1$
# $f_4(x) = f_3(x) + 2*f_2(x) + f_1(x)/2$
# Ответ:  вектора линейно зависимы.

# %% [markdown]
# 3. Найти координаты вектора
# $x=(2,3,5)∈R^3$  в базисе  $b_1=(0,0,10),  b_2=(2,0,0) ,  b_3=(0,1,0)$

# %% [markdown]
# ##### Решение
# $x = 0.2b_1 + 1.5b_2 + 0.2b_3$
# Ответ: x = (0.2,1.5,0.2)

# %% [markdown]
# 4. Найти координаты вектора  $3x^2−2x+2∈R3$:
# а) в базисе  1, x, x^2
# б) в базисе  x^2, x−1, 1

# %% [markdown]
# ##### Решение
# $x = (2,-2,3)$
# a) $x = 0.5b_1 - 0.5b_2 + 1/3 b_3$
# б) $x = 0.5b_1 + 1/3 b_3$

# %% [markdown]
# 5. Установить, является ли линейным подпространством:
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
# б) все векторы, являющиеся линейными комбинациями данных векторов  {u1,u2,...,un}.

# %% [markdown]
# ##### Решение
#
# а)
# $(0,a,b)+(0,с,d)=(c,a+с,b+d)$
# $α⋅(0,a,b)=(0,αa,αb)$
#  Ответ: совокупность векторов является линейным подпространством
# б)

# %% [markdown]
# # Урок 2

# %% [markdown]
# ### Линейное пространство. Основные понятия. Часть 2

# %% [markdown]
# 1. Найти скалярное произведение векторов  $x,y∈R$
# а)  $x=(0,−3,6), y=(−4,7,9)$
# б)  $x=(7,−4,0,1), y=(−3,1,11,2)$

# %% [markdown]
# ##### Решение
#
# а) $(x,y) = 0*-4 -3*7 + 6*9 = 33$
# б) $(x,y) = -21 -4 + 2 = -23$

# %% [markdown]
# 2. Найти нормы векторов  (4,2,4)  и  (12,3,4)  и угол между ними.
#
# $l_1(4,2,4) = 10$
# $l_2(4,2,4) = 6$
# $l_1(12,3,4) = 19$
# $l_1(12,3,4) = 13$
#
# $cos{\phi}=\frac{4*12+2*3+4*4}{6*13}=0.897$

# %% [markdown]
# 3. Будет ли линейное пространство евклидовым, если за скалярное произведение принять:
# а) произведение длин векторов;
# б) утроенное обычное скалярное произведение векторов?

# %% [markdown]
# ##### Решение
#
# 1)  $(x,y)=(y,x)$
# 2)  $(λx,y)=λ(x,y)$
# 3)  $(x_1+x_2,y)=(x_1,y)+(x_2,y)$
# 4)  $(x,x)≥0 , причем  (x,x)=0⇔x=0$
#
# а)
#     $|x||y| = |y||x|$ выполняется
#     $|λx||y| != λ|x||y|$ не выполняется
#
# б)
#     $3(x,y)=3(y,x)$ выполняется
#     $3(λx,y)=λ3(x,y)$ выполняется
#     $3(x_1+x_2,y)=3(x_1,y)+3(x_2,y)$ выполняется
#     $3(x,x)≥0 , причем  3(x,x)=0⇔x=0$ выполняется

# %% [markdown]
# 4. Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве  $R^3$
# а)  $(1,0,0),(0,0,1)$
# б)  $(1/\sqrt{2},−1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0),(0,0,1)$
# в)  $(1/2,−1/2,0),(0,1/2,1/2),(0,0,1)$
# г)  $(1,0,0),(0,1,0),(0,0,1)$

# %% [markdown]
# ##### Решение
# $(x,y)=0$
# $(ei,ej)=0 ∀ i≠j  и  (ei,ei)=1 ∀ i∈[1,n]$
#
# a)
# $x=(1,0,0),y=(0,0,1)$
# $(x,y)=0,  |x|=1, |y|=1$ +
#
# б)
# $x=(1/\sqrt{2},−1/\sqrt{2},0), y=(1/\sqrt{2},1/\sqrt{2},0),z=(0,0,1)$
# $(x,y,z)=0, |x|=1, |y|=1, |z|=1$ +
#
# в)
# $x=(1/2,−1/2,0), y=(0,1/2,1/2),z=(0,0,1)$
# $(x,y,z)=0, |x|=1/2, |y|=1/2, |z|=1$ -
#
# г)
# $x=(1,0,0),y=(0,1,0),z=(0,0,1)$
# $(x,y)=0,  |x|=1, |y|=1, |z|=1$ +
